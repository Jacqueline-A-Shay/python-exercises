# %%
# use iris database 
from pydataset import data
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# convert to pandas dataset and preview data
iris = data('iris')
iris = pd.DataFrame(iris)
iris
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width     Species
# 1             5.1          3.5           1.4          0.2      setosa
# 2             4.9          3.0           1.4          0.2      setosa
# 3             4.7          3.2           1.3          0.2      setosa
# 4             4.6          3.1           1.5          0.2      setosa
# 5             5.0          3.6           1.4          0.2      setosa
# 6             5.4          3.9           1.7          0.4      setosa
# 7             4.6          3.4           1.4          0.3      setosa
# 8             5.0          3.4           1.5          0.2      setosa
# 9             4.4          2.9           1.4          0.2      setosa
# 10            4.9          3.1           1.5          0.1      setosa
# 11            5.4          3.7           1.5          0.2      setosa
# 12            4.8          3.4           1.6          0.2      setosa
# ...

# %%
# What does the distribution of petal lengths look like?
sns.distplot(iris['Petal.Length'])
plt.show()
plt.close()

# %%
# Is there a correlation between petal length and petal width?

from scipy import stats
slope, intercept, r_value, p_value, std_err = stats.linregress(iris["Petal.Length"],iris["Petal.Width"])

ax = sns.regplot(x = "Petal.Length", y = "Petal.Width", data = iris, color='b', 
                 line_kws={'label':"y={0:.1f}x+{1:.1f}".format(slope,intercept)})

ax.legend() # plot legend
plt.show()
plt.close()

# sns.regplot(x = "Petal.Length", y = "Petal.Width", data = iris, corr_func=stats.pearsonr)

# %%
sns.relplot(x = "Petal.Length", y = "Petal.Width", data = iris)
plt.text(5,
         iris["Petal.Length"].corr(iris["Petal.Width"]), # s
         'Correlation Coefficient: {:.2f}'.format(iris["Petal.Length"].corr(iris["Petal.Width"])),
        fontsize = 16) # annotate correlation 
plt.show()
plt.close()

# %%
iris.corr() #Sepal.Length highly correlate with Petal.Length and .Width
# Out:
#               Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# Sepal.Length      1.000000    -0.117570      0.871754     0.817941
# Sepal.Width      -0.117570     1.000000     -0.428440    -0.366126
# Petal.Length      0.871754    -0.428440      1.000000     0.962865
# Petal.Width       0.817941    -0.366126      0.962865     1.000000

# %%
pd.crosstab(iris["Petal.Length"], iris.Species)
sns.heatmap(pd.crosstab(iris["Petal.Length"], iris.Species))
plt.show()
plt.close()

# %%
pd.crosstab(iris["Petal.Width"], iris.Species)
sns.heatmap(pd.crosstab(iris["Petal.Width"], iris.Species))
plt.show()
plt.close()

# %%
pd.crosstab(iris["Sepal.Length"], iris.Species)
sns.heatmap(pd.crosstab(iris["Sepal.Length"], iris.Species))
plt.show()
plt.close()

# %%
iris.pivot_table('total_bill', 'size', ['smoker', 'time'], aggfunc='max')

# %%
pd.crosstab(iris["Sepal.Width"], iris.Species)
sns.heatmap(pd.crosstab(iris["Sepal.Width"], iris.Species))
plt.show()
plt.close()

# %%
sns.heatmap(iris.corr())

# %%
# plt.figure(figsize=(12, 10))
# plt.suptitle('Finding Predictor for Species with Sepal and Petal Characteristics')

# plt.subplot(221)
# sns.relplot(x='Petal.Length', y='Sepal.Width', hue='Species', data=iris)
# plt.title('Petal Length & Sepal Width')

# plt.subplot(222)
# sns.relplot(x='Petal.Length', y='Sepal.Length', hue='Species', data=iris)
# plt.title('Petal Length & Sepal Length')

# plt.subplot(223)
# sns.relplot(x='Petal.Width', y='Sepal.Width', hue='Species', data=iris)
# plt.title('Petal Width & Sepal Width')

# plt.subplot(224)
# sns.relplot(x='Petal.Width', y='Sepal.Length', hue='Species', data=iris)
# plt.title('Petal Width & Sepal Length')

# plt.subplots_adjust(hspace=0.4)
# plt.show()
# plt.close()

# %%
# Would it be reasonable to predict species based on sepal width and sepal length?
sns.relplot(x='Sepal.Width', y='Sepal.Length', hue='Species', data=iris)
plt.show()
plt.close()

# %%
# Which features would be best used to predict species?
sns.pairplot(iris)

# %%
# Use the iris database to answer the following quesitons:

# %%
# What does the distribution of petal lengths look like?
sns.distplot(iris["Petal.Length"])

# %%
# Is there a correlation between petal length and petal width?
sns.relplot(data = iris, x = "Petal.Length", y = "Petal.Width" )
r = iris.corr().loc["Petal.Length","Petal.Width"] # df.corr() gives another pandas dataframe

plt.text(1.5, 2.0, f'r = {r:.2}')
# Out:
# Text(1.5, 2.0, 'r = 0.96')

# %%
# Would it be reasonable to predict species based on sepal width and sepal length?
sns.relplot(data = iris, x ='Sepal.Width', y = 'Sepal.Length', hue = 'Species')

# %%
# Would it be reasonable to predict species based on sepal width and sepal length?

iris['Sepal_lentowid'] = iris['Sepal.Length']/iris['Sepal.Width']
sns.boxplot(data = iris, x = 'Species', y = 'Sepal_lentowid')

# %%
# Which features would be best used to predict species?
sns.pairplot(data=iris, hue = "Species")

# %%
# Using the lesson as an example, 
# use seaborn's load_dataset function to load the anscombe data set. 
# Use pandas to group the data by the dataset column, 
# and calculate summary statistics for each dataset. What do you notice?

# Plot the x and y values from the anscombe data. 
# Each dataset should be in a separate column.

# %%
anscombe = sns.load_dataset('anscombe')
anscombe.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
anscombe.groupby('dataset').describe()
# Out:
#             x                                               y            \
#         count mean       std  min  25%  50%   75%   max count      mean
# dataset
# I        11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500909
# II       11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500909
# III      11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500000
# IV       11.0  9.0  3.316625  8.0  8.0  8.0   8.0  19.0  11.0  7.500909
#
#
#               std   min    25%   50%   75%    max
# dataset
# I        2.031568  4.26  6.315  7.58  8.57  10.84
# II       2.031657  3.10  6.695  8.14  8.95   9.26
# III      2.030424  5.39  6.250  7.11  7.98  12.74
# IV       2.030579  5.25  6.170  7.04  8.19  12.50

# %%
sns.relplot(data = anscombe, x = 'x', y = 'y', col = 'dataset')

# %%
# InsectSprays dataset

# %%
# use  boxplot that shows the effectiveness of the different insect sprays
from pydataset import data 
InsectSprays = data('InsectSprays')
InsectSprays = pd.DataFrame(InsectSprays)
InsectSprays 
sns.boxplot(data = InsectSprays, y = 'count', x = 'spray')

# %%
# use swiss dataset 
# Create an attribute named is_catholic that holds a boolean value of whether or not the province is Catholic. 
# (Choose a cutoff point for what constitutes catholic)
swiss = data('swiss')
swiss = pd.DataFrame(swiss)
swiss.head()
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Courtelary         80.2         17.0           15         12      9.96
# Delemont           83.1         45.1            6          9     84.84
# Franches-Mnt       92.5         39.7            5          5     93.40
# Moutier            85.8         36.5           12          7     33.77
# Neuveville         76.9         43.5           17         15      5.16
#
#               Infant.Mortality
# Courtelary                22.2
# Delemont                  22.2
# Franches-Mnt              20.2
# Moutier                   20.3
# Neuveville                20.6

# %%
data('swiss', show_doc=True)
# Out:
# swiss
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Swiss Fertility and Socioeconomic Indicators (1888) Data
#
# ### Description
#
# Standardized fertility measure and socio-economic indicators for each of 47
# French-speaking provinces of Switzerland at about 1888.
#
# ### Usage
#
#     data(swiss)
#
# ### Format
#
# A data frame with 47 observations on 6 variables, each of which is in percent,
# i.e., in [0,100].
#
# [,1] Fertility Ig, "common standardized fertility measure" [,2] Agriculture
# [,3] Examination nation [,4] Education [,5] Catholic [,6] Infant.Mortality
# live births who live less than 1 year.
#
# All variables but 'Fert' give proportions of the population.
#
# ### Source
#
# Project "16P5", pages 549-551 in
#
# Mosteller, F. and Tukey, J. W. (1977) “Data Analysis and Regression: A Second
# Course in Statistics”. Addison-Wesley, Reading Mass.
#
# ...

# %%
swiss.describe()
# Out:
#        Fertility  Agriculture  Examination  Education   Catholic  \
# count  47.000000    47.000000    47.000000  47.000000   47.00000
# mean   70.142553    50.659574    16.489362  10.978723   41.14383
# std    12.491697    22.711218     7.977883   9.615407   41.70485
# min    35.000000     1.200000     3.000000   1.000000    2.15000
# 25%    64.700000    35.900000    12.000000   6.000000    5.19500
# 50%    70.400000    54.100000    16.000000   8.000000   15.14000
# 75%    78.450000    67.650000    22.000000  12.000000   93.12500
# max    92.500000    89.700000    37.000000  53.000000  100.00000
#
#        Infant.Mortality
# count         47.000000
# mean          19.942553
# std            2.912697
# min           10.800000
# 25%           18.150000
# 50%           20.000000
# 75%           21.700000
# max           26.600000

# %%
swiss['is_catholic'] = swiss.Catholic >= 15
swiss
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Courtelary         80.2         17.0           15         12      9.96
# Delemont           83.1         45.1            6          9     84.84
# Franches-Mnt       92.5         39.7            5          5     93.40
# Moutier            85.8         36.5           12          7     33.77
# Neuveville         76.9         43.5           17         15      5.16
# Porrentruy         76.1         35.3            9          7     90.57
# Broye              83.8         70.2           16          7     92.85
# Glane              92.4         67.8           14          8     97.16
# Gruyere            82.4         53.3           12          7     97.67
# Sarine             82.9         45.2           16         13     91.38
# Veveyse            87.1         64.5           14          6     98.61
# Aigle              64.1         62.0           21         12      8.52
# ...

# %%
# Does whether or not a province is Catholic influence fertility?
sns.heatmap(pd.crosstab(swiss["Fertility"], swiss.is_catholic))

# %%
swiss.is_catholic.corr(swiss.Fertility)
# Out:
# 0.2110516427465248

# %%
# What measure correlates most strongly with fertility? #Catholic%
swiss.corr()
# Out:
#                   Fertility  Agriculture  Examination  Education  Catholic  \
# Fertility          1.000000     0.353079    -0.645883  -0.663789  0.463685
# Agriculture        0.353079     1.000000    -0.686542  -0.639523  0.401095
# Examination       -0.645883    -0.686542     1.000000   0.698415 -0.572742
# Education         -0.663789    -0.639523     0.698415   1.000000 -0.153859
# Catholic           0.463685     0.401095    -0.572742  -0.153859  1.000000
# Infant.Mortality   0.416556    -0.060859    -0.114022  -0.099322  0.175496
# is_catholic        0.211052     0.212868    -0.311404   0.114144  0.836156
#
#                   Infant.Mortality  is_catholic
# Fertility                 0.416556     0.211052
# Agriculture              -0.060859     0.212868
# Examination              -0.114022    -0.311404
# Education                -0.099322     0.114144
# Catholic                  0.175496     0.836156
# Infant.Mortality          1.000000     0.168073
# ...

# %%
sns.heatmap(swiss.corr())

# %%
print('Feature correlations with fertility')
print(swiss.corr().Fertility.sort_values())

sns.heatmap(swiss.corr(), annot=True, center=0)
# Out:
# Feature correlations with fertility
# Education          -0.663789
# Examination        -0.645883
# is_catholic         0.211052
# Agriculture         0.353079
# Infant.Mortality    0.416556
# Catholic            0.463685
# Fertility           1.000000
# Name: Fertility, dtype: float64

# %%
# Load the swiss dataset and read it's documentation. 
# Create visualizations to answer the following questions:

# Create an attribute named is_catholic that holds a boolean value 
# of whether or not the province is Catholic. (Choose a cutoff point for what constitutes catholic)
# Does whether or not a province is Catholic influence fertility?
# What measure correlates most strongly with fertility?

# %%
swiss = data('swiss')
swiss.head()
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Courtelary         80.2         17.0           15         12      9.96
# Delemont           83.1         45.1            6          9     84.84
# Franches-Mnt       92.5         39.7            5          5     93.40
# Moutier            85.8         36.5           12          7     33.77
# Neuveville         76.9         43.5           17         15      5.16
#
#               Infant.Mortality
# Courtelary                22.2
# Delemont                  22.2
# Franches-Mnt              20.2
# Moutier                   20.3
# Neuveville                20.6

# %%
sns.distplot(swiss.Catholic, bins = 10) # big gap, thus good to use T/F

# %%
# if seems there are distinct groups, convert to categorical
swiss['is_catholic'] = swiss.Catholic.apply(lambda n: 'Catholic' if n > 70 else 'Not Catholic')

sns.boxplot(data=swiss, y='Fertility', x='is_catholic')

# %%
swiss.corr().Fertility
# Out:
# Fertility           1.000000
# Agriculture         0.353079
# Examination        -0.645883
# Education          -0.663789
# Catholic            0.463685
# Infant.Mortality    0.416556
# Name: Fertility, dtype: float64

# %%
sns.relplot(data=swiss, x='Catholic', y='Fertility', hue='is_catholic')

# %%
# Using the chipotle dataset from the previous exercise, 
# create a bar chart that shows the 4 most popular items and the revenue produced by each.

# Getting data from SQL databases
# Create a function, get_db_url. 
# accept a username, hostname, password, and database name 
# return a url to for accessing database in SQL server

def get_db_url():
    url = f'mysql+pymysql://{user}:{password}@{host}/{database_name}'
    return url
from env import host, user, password
database_name = input("Input desired database name: ")
query = input("Key in the query")
chipotle = pd.read_sql(query,get_db_url())
chipotle.head(5)
# Out:
# Input desired database name: chipotle
# Key in the queryselect * from orders
#    id  order_id  quantity                              item_name  \
# 0   1         1         1           Chips and Fresh Tomato Salsa
# 1   2         1         1                                   Izze
# 2   3         1         1                       Nantucket Nectar
# 3   4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4   5         2         2                           Chicken Bowl
#
#                                                            choice_description  \
# 0                                                                         nan
# 1                                                                [Clementine]
# 2                                                                     [Apple]
# 3                                                                         nan
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]
#
#   item_price
# 0     $2.39
# ...

# %%
chipotle["item_price"] = chipotle.item_price.str.strip("$")
chipotle
# Out:
#         id  order_id  quantity                              item_name  \
# 0        1         1         1           Chips and Fresh Tomato Salsa
# 1        2         1         1                                   Izze
# 2        3         1         1                       Nantucket Nectar
# 3        4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4        5         2         2                           Chicken Bowl
# 5        6         3         1                           Chicken Bowl
# 6        7         3         1                          Side of Chips
# 7        8         4         1                          Steak Burrito
# 8        9         4         1                       Steak Soft Tacos
# 9       10         5         1                          Steak Burrito
# 10      11         5         1                    Chips and Guacamole
# 11      12         6         1                   Chicken Crispy Tacos
# ...

# %%
chipotle["item_price"] = chipotle.item_price.astype(float)

# %%
chipotle.dtypes
# Out:
# id                      int64
# order_id                int64
# quantity                int64
# item_name              object
# choice_description     object
# item_price            float64
# dtype: object

# %%
# create a bar chart that shows the 4 most popular items and the revenue produced by each.
vis_data_4_popular_revenue = chipotle[["item_name","quantity","item_price"]]
vis_data_4_popular_revenue
# Out:
#                                   item_name  quantity  item_price
# 0              Chips and Fresh Tomato Salsa         1        2.39
# 1                                      Izze         1        3.39
# 2                          Nantucket Nectar         1        3.39
# 3     Chips and Tomatillo-Green Chili Salsa         1        2.39
# 4                              Chicken Bowl         2       16.98
# 5                              Chicken Bowl         1       10.98
# 6                             Side of Chips         1        1.69
# 7                             Steak Burrito         1       11.75
# 8                          Steak Soft Tacos         1        9.25
# 9                             Steak Burrito         1        9.25
# 10                      Chips and Guacamole         1        4.45
# 11                     Chicken Crispy Tacos         1        8.75
# 12                       Chicken Soft Tacos         1        8.75
# ...

# %%
top_4 = vis_data_4_popular_revenue.groupby(['item_name','item_price'], as_index=False).quantity.count()
top_4
# Out:
#                                  item_name  item_price  quantity
# 0                        6 Pack Soft Drink        6.49        53
# 1                        6 Pack Soft Drink       12.98         1
# 2                            Barbacoa Bowl        8.69         3
# 3                            Barbacoa Bowl        8.99         8
# 4                            Barbacoa Bowl        9.25        28
# 5                            Barbacoa Bowl       11.48         6
# 6                            Barbacoa Bowl       11.49         1
# 7                            Barbacoa Bowl       11.75        20
# 8                         Barbacoa Burrito        8.69         2
# 9                         Barbacoa Burrito        8.99        19
# 10                        Barbacoa Burrito        9.25        46
# 11                        Barbacoa Burrito       11.08         1
# 12                        Barbacoa Burrito       11.48         1
# ...

# %%
top_4.sort_values(by = 'quantity',ascending = False)
# Out:
#                                  item_name  item_price  quantity
# 127                    Chips and Guacamole        4.45       349
# 72                            Chicken Bowl        8.75       313
# 41                       Canned Soft Drink        1.25       264
# 84                         Chicken Burrito        8.75       230
# 75                            Chicken Bowl       11.25       228
# 115                                  Chips        2.15       192
# 87                         Chicken Burrito       11.25       131
# 26                           Bottled Water        1.50       117
# 165                          Steak Burrito        8.99       113
# 166                          Steak Burrito        9.25       108
# 70                            Chicken Bowl        8.49       104
# 83                         Chicken Burrito        8.49       103
# 169                          Steak Burrito       11.75       100
# ...

# %%
top_4['item_name'] = top_4["item_name"].str.replace(' ','_')
top_4
# Out:
#                                  item_name  item_price  quantity
# 0                        6_Pack_Soft_Drink        6.49        53
# 1                        6_Pack_Soft_Drink       12.98         1
# 2                            Barbacoa_Bowl        8.69         3
# 3                            Barbacoa_Bowl        8.99         8
# 4                            Barbacoa_Bowl        9.25        28
# 5                            Barbacoa_Bowl       11.48         6
# 6                            Barbacoa_Bowl       11.49         1
# 7                            Barbacoa_Bowl       11.75        20
# 8                         Barbacoa_Burrito        8.69         2
# 9                         Barbacoa_Burrito        8.99        19
# 10                        Barbacoa_Burrito        9.25        46
# 11                        Barbacoa_Burrito       11.08         1
# 12                        Barbacoa_Burrito       11.48         1
# ...

# %%
top_4 = top_4.reset_index()
top_4
# Out:
#                                  item_name  index  item_price  quantity
# 0                        6_Pack_Soft_Drink      0        6.49        53
# 1                        6_Pack_Soft_Drink      1       12.98         1
# 2                            Barbacoa_Bowl      2        8.69         3
# 3                            Barbacoa_Bowl      3        8.99         8
# 4                            Barbacoa_Bowl      4        9.25        28
# 5                            Barbacoa_Bowl      5       11.48         6
# 6                            Barbacoa_Bowl      6       11.49         1
# 7                            Barbacoa_Bowl      7       11.75        20
# 8                         Barbacoa_Burrito      8        8.69         2
# 9                         Barbacoa_Burrito      9        8.99        19
# 10                        Barbacoa_Burrito     10        9.25        46
# 11                        Barbacoa_Burrito     11       11.08         1
# ...

# %%
plot_top_4 = top_4.nlargest(4,'quantity')
plot_top_4['revenue'] = plot_top_4.quantity * plot_top_4.item_price
plot_top_4 = plot_top_4.reset_index()
plot_top_4
# Out:
#    level_0            item_name  index  item_price  quantity  revenue
# 0      127  Chips_and_Guacamole    127        4.45       349  1553.05
# 1       72         Chicken_Bowl     72        8.75       313  2738.75
# 2       41    Canned_Soft_Drink     41        1.25       264   330.00
# 3       84      Chicken_Burrito     84        8.75       230  2012.50

# %%
g = sns.barplot(x = plot_top_4.index, y = plot_top_4.quantity)

# for p in g.patches:
#     g.annotate(format(p.get_height(), '.2f'), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')

# %%
for i, row in plot_top_4.iterrows():
    print(i,row['revenue'])
# Out:
# 0 1553.05
# 1 2738.75
# 2 330.0
# 3 2012.5

# %%
plt.figure(figsize=(10,10))
p = sns.barplot(x = plot_top_4.item_name, y = plot_top_4.quantity)

# for i, row in plot_top_4.iterrows():
#     height = p.get_height()
#     p.annotate('{}'.format(row['revenue']),
#                     xy=(rect.get_x() + rect.get_width() / 2, height),
#                     xytext=(0, 3),  # 3 points vertical offset
#                     textcoords="offset points",
#                     ha='center', va='bottom')
for i, row in plot_top_4.iterrows():
    p.annotate(row['revenue'], xy = (i,(row['quantity']+10)))

# %%
plot_top_4
# Out:
#                item_name  item_price  quantity  revenue
# 127  Chips and Guacamole        4.45       349  1553.05
# 72          Chicken Bowl        8.75       313  2738.75
# 41     Canned Soft Drink        1.25       264   330.00
# 84       Chicken Burrito        8.75       230  2012.50

# %%
# chipotle.item_price.str.replace('$','').astype('float')

# %%
popular_4 = (chipotle.groupby("item_name")
 .sum()
.drop(columns='order_id')
.rename(columns={'quantity':'unit_sold','item_price':'revenue'})
.sort_values(by = 'unit_sold', ascending = False)
.head(4)
.reset_index())

popular_4
# Out:
#              item_name       id  unit_sold  revenue
# 0         Chicken Bowl  1780635        761  7342.73
# 1      Chicken Burrito  1238770        591  5575.82
# 2  Chips and Guacamole  1122252        506  2201.04
# 3        Steak Burrito   818163        386  3851.43

# %%
plt.figure(figsize=(10,10))
ax = sns.barplot(data=popular_4, y = 'revenue', x = 'item_name') 
# swap x y content x ='rev' y = 'item_name', will become horizontal
for i, row in popular_4.iterrows():
    ax.annotate('{:.2f}'.format(row['revenue']), xy = (i,(row['revenue']+100)))

# %%
# Load the sleepstudy data and read it's documentation. 
# Use seaborn to create a line chart of all the individual subject's reaction times 
# and a more prominant line showing the average change in reaction time.

sleepstudy = data('sleepstudy')
sleepstudy = pd.DataFrame(sleepstudy)
sleepstudy
# Out:
#      Reaction  Days  Subject
# 1    249.5600     0      308
# 2    258.7047     1      308
# 3    250.8006     2      308
# 4    321.4398     3      308
# 5    356.8519     4      308
# 6    414.6901     5      308
# 7    382.2038     6      308
# 8    290.1486     7      308
# 9    430.5853     8      308
# 10   466.3535     9      308
# 11   222.7339     0      309
# 12   205.2658     1      309
# 13   202.9778     2      309
# 14   204.7070     3      309
# 15   207.7161     4      309
# 16   215.9618     5      309
# 17   213.6303     6      309
# 18   217.7272     7      309
# 19   224.2957     8      309
# 20   237.3142     9      309
# 21   199.0539     0      310
# 22   194.3322     1      310
# 23   234.3200     2      310
# 24   232.8416     3      310
# 25   229.3074     4      310
# 26   220.4579     5      310
# 27   235.4208     6      310
# 28   255.7511     7      310
# 29   261.0125     8      310
# 30   247.5153     9      310
# 31   321.5426     0      330
# ...

# %%
plt.figure(figsize=(12, 12))

sleep = data('sleepstudy')

sleep.Subject = 'subject_' + sleep.Subject.astype('str')

sns.lineplot(data=sleep, y='Reaction', x='Days', linewidth=5, label='Average')
sns.lineplot(data=sleep, y='Reaction', x='Days', hue='Subject')

# %%
sns.relplot(data = sleepstudy, y = 'Reaction', x = 'Days')

# %%
sns.lineplot(data = sleepstudy, y = 'Reaction', x = 'Days')

# %%
plt.figure(figsize=(20, 12))

sns.lineplot(data = sleepstudy, y = 'Reaction', x = 'Days', hue = 'Subject')

# %%
# even if change type into str for Subject, sns will still treat a int
plt.figure(figsize=(20, 12))

sleepstudy.Subject = 'subject_' + sleepstudy.Subject.astype(str)
sns.lineplot(data = sleepstudy, y = 'Reaction', x = 'Days', hue = 'Subject')

# %%
plt.figure(figsize=(20, 12))

sns.lineplot(data = sleepstudy, y = 'Reaction', x = 'Days', hue = 'Subject')
sns.lineplot(data = sleepstudy, y = 'Reaction', x = 'Days') # run together, will superimpose
